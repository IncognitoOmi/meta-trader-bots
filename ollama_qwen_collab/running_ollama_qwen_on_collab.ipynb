# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# ERROR: This version requires zstd for extraction. Please install zstd and try again:
#   - Debian/Ubuntu: sudo apt-get install zstd
#   - RHEL/CentOS/Fedora: sudo dnf install zstd
#   - Arch: sudo pacman -S zstd

# %%
# !apt-get install -y zstd
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   zstd
# 0 upgraded, 1 newly installed, 0 to remove and 52 not upgraded.
# Need to get 644 kB of archives.
# After this operation, 1,845 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 zstd amd64 1.5.5+dfsg2-2build1.1 [644 kB]
# Fetched 644 kB in 1s (879 kB/s)
# Selecting previously unselected package zstd.
# (Reading database ... 126952 files and directories currently installed.)
# Preparing to unpack .../zstd_1.5.5+dfsg2-2build1.1_amd64.deb ...
# Unpacking zstd (1.5.5+dfsg2-2build1.1) ...
# Setting up zstd (1.5.5+dfsg2-2build1.1) ...
# Processing triggers for man-db (2.12.0-4build2) ...

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
import subprocess
import time

# Server ko background me start karna
subprocess.Popen(["ollama", "serve"])
time.sleep(3)

# Model download (pull) karna
# !ollama pull qwen2.5-coder:7b

# %%
# !pip install pyngrok
from pyngrok import ngrok

# Apna token yahan paste kar
ngrok.set_auth_token("3J9aAJGzxTNNhek8otQ0fgL4JQ6_5ZtiCzEXq5wFPqEfYgf9J")

# Port 11434 (Ollama) ko expose kar rahe hain
public_url = ngrok.connect(11434).public_url

print("=========================================")
print(f"CLINE BASE URL: {public_url}")
print("=========================================")
# Out:
# ...
# CLINE BASE URL: https://liability-canine-concave.ngrok-free.dev
# ...

# %%
import os
import subprocess
import time
import re

# 1. Purana server band karo
os.system("pkill ollama")
time.sleep(2)

# 2. Security bypass karke Ollama wapas start karo
env = os.environ.copy()
env["OLLAMA_ORIGINS"] = "*"
subprocess.Popen(["ollama", "serve"], env=env)
time.sleep(3)

# 3. Cloudflare tunnel chalu karo (No blocking, no tokens needed)
# !wget -q -nc https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# !chmod +x cloudflared-linux-amd64

process = subprocess.Popen(['./cloudflared-linux-amd64', 'tunnel', '--url', 'http://127.0.0.1:11434'], stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
time.sleep(5)

print("======================================================")
for line in iter(process.stdout.readline, b''):
    line_str = line.decode('utf-8')
    if "trycloudflare.com" in line_str:
        match = re.search(r'https://[a-zA-Z0-9-]+\.trycloudflare\.com', line_str)
        if match:
            print(f"NAYA CLINE BASE URL: {match.group(0)}/v1")
            break
print("======================================================")
# Out:
# ...
# NAYA CLINE BASE URL: https://undergraduate-printing-filed-ids.trycloudflare.com/v1
# ...

# %%
import os
import subprocess
import time
from pyngrok import ngrok

# 1. Purane blocked servers band karo
os.system("pkill ollama")
os.system("pkill cloudflared")
time.sleep(2)

# 2. Security bypass settings (Master key)
env = os.environ.copy()
env["OLLAMA_ORIGINS"] = "*"
env["OLLAMA_HOST"] = "0.0.0.0"

# 3. Wapas start karo
subprocess.Popen(["ollama", "serve"], env=env)
time.sleep(3)

# 4. Ngrok ka naya link generate karo
tunnels = ngrok.get_tunnels()
for tunnel in tunnels:
    ngrok.disconnect(tunnel.public_url)

public_url = ngrok.connect(11434).public_url

print("======================================================")
print(f"NAYA CLINE BASE URL: {public_url}/v1")
print("======================================================")
# Out:
# WARNING:pyngrok.process.ngrok:t=2026-09-10T21:40:27+0000 lvl=warn msg="Stopping forwarder" name=http-11434-6e4379a1-0cb3-47d3-9abf-c7a1ae1ce823 acceptErr="failed to accept connection: Listener closed"
# ...
# NAYA CLINE BASE URL: https://liability-canine-concave.ngrok-free.dev/v1
# ...

# %% [markdown]
# **1. Google Colab (Hardware Setup)**
#
# * Google Colab open karke **Runtime** > **Change runtime type** me jaakar **T4 GPU** select karna hai. (Isse tere 8GB RAM wale laptop se load hat jayega).
#
# **2. Colab Server & Tunnel (Master Script)**
#
# * Colab ke cell me ye final code run karna hai. Ye Ollama install karega, uski strict security bypass karega, Qwen model download karega, aur Ngrok ke through public link banayega:
#
# ```python
# import os, subprocess, time
# from pyngrok import ngrok
#
# # 1. Install Ollama & Dependencies
# !apt-get install -y zstd > /dev/null
# !curl -fsSL https://ollama.com/install.sh | sh
#
# # 2. Security Bypass (403 Forbidden Error Fix) & Start Server
# env = os.environ.copy()
# env["OLLAMA_ORIGINS"] = "*"
# env["OLLAMA_HOST"] = "0.0.0.0"
# subprocess.Popen(["ollama", "serve"], env=env)
# time.sleep(3)
#
# # 3. Model Download
# !ollama pull qwen2.5-coder:7b
#
# # 4. Ngrok Tunnel (Apna Ngrok token yahan dalna hai)
# ngrok.set_auth_token("TERA_NGROK_AUTH_TOKEN_YAHAN_DAAL")
# public_url = ngrok.connect(11434).public_url
# print(f"CLINE BASE URL: {public_url}/v1")
#
# ```
#
# **3. VS Code (Cline Settings)**
#
# * **API Provider:** `OpenAI Compatible` select kiya. (Ollama ya Gemini nahi).
# * **Base URL:** Colab me print hua Ngrok link yahan paste kiya, aur aage exactly `/v1` lagaya (e.g., `[https://xyz.ngrok-free.dev/v1](https://xyz.ngrok-free.dev/v1)`).
# * **API Key:** `ollama` ya `12345` daala. (Isko khali chhodne se error aata hai).
# * **Model ID:** `qwen2.5-coder:7b` type kiya.
# * **Reasoning Effort:** Dropdown me se **None / Disable** select kiya. (Taaki `"does not support thinking"` wala error na aaye, kyunki Qwen standard model hai).
